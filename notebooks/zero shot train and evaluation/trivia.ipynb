# %%
# Cell 1 — setup (as always)
# %cd /kaggle/working
# !cp -r /kaggle/input/datasets/anfs2003/ragtruth-lettucedetect/lettucedetect_code/LettuceDetect .
# %cd LettuceDetect
# !pip install -q -e .

# %%
import os
from kaggle_secrets import UserSecretsClient
os.environ["HF_TOKEN"] = UserSecretsClient().get_secret("HF_WRITE")

# %%
# Cell 3 — full model (test + calibration on valid)
# !python /kaggle/input/datasets/anfs2003/ragtruth-lettucedetect/eval_triviaplus.py \
    --model-path anfs4554/lettucedetect-full-large \
    --data-path /kaggle/input/datasets/anfs2003/ragtruth-lettucedetect/triviaplus.jsonl \
    --calibrate --output-dir /kaggle/working/trivia_results
# Out:
# [data] split=test: 645 total, -27 gray, -44 over token limit -> 574 evaluated
# config.json: 2.09kB [00:00, 5.94MB/s]
# model.safetensors: 100%|████████████████████| 1.58G/1.58G [00:14<00:00, 106MB/s]
# Loading weights: 100%|█| 174/174 [00:00<00:00, 1551.59it/s, Materializing param=
# tokenizer_config.json: 100%|███████████████████| 351/351 [00:00<00:00, 1.77MB/s]
# tokenizer.json: 3.58MB [00:00, 10.9MB/s]
# Scoring lettucedetect-full-large_triviaplus-test_maxlen8192:   0%| | 0/574 [00:0W0715 22:50:28.701000 178 torch/_inductor/utils.py:1679] [1/0_1] Not enough SMs to use max_autotune_gemm mode
# Scoring lettucedetect-full-large_triviaplus-test_maxlen8192: 100%|█| 574/574 [05
# [data] split=valid: 316 total, -14 gray, -14 over token limit -> 288 evaluated
# Loading weights: 100%|█| 174/174 [00:00<00:00, 1725.87it/s, Materializing param=
# Scoring calibration(valid): 100%|█████████████| 288/288 [02:08<00:00,  2.24it/s]
#
# ===== lettucedetect-full-large_triviaplus-test_maxlen8192 =====
# n=574 (positives=184)
# Default thr 0.50: F1=0.5239 CI(0.46388016180515124, 0.5743380855397149)  P=0.4242 R=0.6848  BalAcc=0.6232 CI(0.5819787691194509, 0.6673732696477123)
# AUROC=0.6234 CI(0.575260890679709, 0.6711136354384095)
# Calibrated thr 0.4624 (on valid): F1=0.5344 CI(0.47678306864554365, 0.5833375251509054)  P=0.4258 R=0.7174  BalAcc=0.6305
# Inference: 311.99s total, 0.5435s/example
#
# Saved: /kaggle/working/trivia_results/lettucedetect-full-large_triviaplus-test_maxlen8192.json + _per_example.csv

# %%
# Cell 4 — QA-only model (swap in your actual HF repo id, or a local path if you
# attached the QA zip as a dataset instead)
# !python /kaggle/input/datasets/anfs2003/ragtruth-lettucedetect/eval_triviaplus.py \
    --model-path anfs4554/lettucedetect-qa-only-large \
    --data-path /kaggle/input/datasets/anfs2003/ragtruth-lettucedetect/triviaplus.jsonl \
    --calibrate --output-dir /kaggle/working/trivia_results
# Out:
# [data] split=test: 645 total, -27 gray, -44 over token limit -> 574 evaluated
# config.json: 2.09kB [00:00, 4.95MB/s]
# model.safetensors: 100%|████████████████████| 1.58G/1.58G [00:13<00:00, 115MB/s]
# Loading weights: 100%|█| 174/174 [00:00<00:00, 1778.53it/s, Materializing param=
# tokenizer_config.json: 100%|███████████████████| 351/351 [00:00<00:00, 1.57MB/s]
# tokenizer.json: 3.58MB [00:00, 29.7MB/s]
# Scoring lettucedetect-qa-only-large_triviaplus-test_maxlen8192: 100%|█| 574/574
# [data] split=valid: 316 total, -14 gray, -14 over token limit -> 288 evaluated
# Loading weights: 100%|█| 174/174 [00:00<00:00, 1521.94it/s, Materializing param=
# Scoring calibration(valid): 100%|█████████████| 288/288 [02:08<00:00,  2.24it/s]
#
# ===== lettucedetect-qa-only-large_triviaplus-test_maxlen8192 =====
# n=574 (positives=184)
# Default thr 0.50: F1=0.4505 CI(0.39919614020014954, 0.49820346320346315)  P=0.3505 R=0.6304  BalAcc=0.5396 CI(0.49534495056967837, 0.5828896407899217)
# AUROC=0.5285 CI(0.4805429017856692, 0.5789540565506343)
# Calibrated thr 0.1574 (on valid): F1=0.4885 CI(0.43877973179443763, 0.5314049420745999)  P=0.3397 R=0.8696  BalAcc=0.5361
# Inference: 307.59s total, 0.5359s/example
#
# Saved: /kaggle/working/trivia_results/lettucedetect-qa-only-large_triviaplus-test_maxlen8192.json + _per_example.csv

# %%
# Cell 5 — grab results (small files)
# !cd /kaggle/working && zip -qr trivia_results.zip trivia_results
