# %%
# Cell 1 — setup
# %cd /kaggle/working
# !cp -r /kaggle/input/datasets/anfs2003/ragtruth-lettucedetect/lettucedetect_code/LettuceDetect .
# %cd LettuceDetect
# !pip install -q -e .

# %%
import os
from kaggle_secrets import UserSecretsClient
os.environ["HF_TOKEN"] = UserSecretsClient().get_secret("HF_WRITE")

# %%
# Cell 3 — full model (test + calibration on valid)
# !python /kaggle/input/datasets/anfs2003/ragtruth-lettucedetect/eval_triviaplus.py \
    --model-path anfs4554/lettucedetect-full-large \
    --data-path /kaggle/input/datasets/anfs2003/ragtruth-lettucedetect/triviaplus.jsonl \
    --calibrate --output-dir /kaggle/working/trivia_results

# %%
# Cell 4 — QA-only model (swap in your actual HF repo id, or a local path if you
# attached the QA zip as a dataset instead)
# !python /kaggle/input/datasets/anfs2003/ragtruth-lettucedetect/eval_triviaplus.py \
    --model-path anfs4554/lettucedetect-qa-only-large \
    --data-path /kaggle/input/datasets/anfs2003/ragtruth-lettucedetect/triviaplus.jsonl \
    --calibrate --output-dir /kaggle/working/trivia_results

# %%
# Cell 5 — grab results (small files)
# !cd /kaggle/working && zip -qr trivia_results.zip trivia_results

# %%
# gray-area sensitivity (protocol §4 requirement)
# !python /kaggle/input/datasets/anfs2003/ragtruth-lettucedetect/eval_triviaplus.py \
    --model-path anfs4554/lettucedetect-full-large \
    --data-path /kaggle/input/datasets/anfs2003/ragtruth-lettucedetect/triviaplus.jsonl \
    --include-gray --output-dir /kaggle/working/trivia_results

# !python /kaggle/input/datasets/anfs2003/ragtruth-lettucedetect/eval_triviaplus.py \
    --model-path anfs4554/lettucedetect-qa-only-large \
    --data-path /kaggle/input/datasets/anfs2003/ragtruth-lettucedetect/triviaplus.jsonl \
    --include-gray --output-dir /kaggle/working/trivia_results
# truncation sensitivity (4096 window)
# !python /kaggle/input/datasets/anfs2003/ragtruth-lettucedetect/eval_triviaplus.py \
    --model-path anfs4554/lettucedetect-full-large \
    --data-path /kaggle/input/datasets/anfs2003/ragtruth-lettucedetect/triviaplus.jsonl \
    --max-length 4096 --output-dir /kaggle/working/trivia_results

# !python /kaggle/input/datasets/anfs2003/ragtruth-lettucedetect/eval_triviaplus.py \
    --model-path anfs4554/lettucedetect-qa-only-large \
    --data-path /kaggle/input/datasets/anfs2003/ragtruth-lettucedetect/triviaplus.jsonl \
    --max-length 4096 --output-dir /kaggle/working/trivia_results
# Out:
# [data] split=test: 645 total, -0 gray, -45 over token limit -> 600 evaluated
# config.json: 2.09kB [00:00, 6.61MB/s]
# model.safetensors: 100%|████████████████████| 1.58G/1.58G [00:08<00:00, 190MB/s]
# Loading weights: 100%|█| 174/174 [00:00<00:00, 1589.19it/s, Materializing param=
# tokenizer_config.json: 100%|███████████████████| 351/351 [00:00<00:00, 2.01MB/s]
# tokenizer.json: 3.58MB [00:00, 50.3MB/s]
# Scoring lettucedetect-full-large_triviaplus-test_maxlen8192_withgray:   0%| | 0/W0715 23:24:10.926000 165 torch/_inductor/utils.py:1679] [1/0_1] Not enough SMs to use max_autotune_gemm mode
# Scoring lettucedetect-full-large_triviaplus-test_maxlen8192_withgray: 100%|█| 60
#
# ===== lettucedetect-full-large_triviaplus-test_maxlen8192_withgray =====
# n=600 (positives=210)
# Default thr 0.50: F1=0.5513 CI(0.4970862296777158, 0.6003498743655712)  P=0.4589 R=0.6905  BalAcc=0.6260 CI(0.5848765856135297, 0.6641737041401864)
# AUROC=0.6266 CI(0.5826089602338282, 0.6737452790343036)
# ...
